# %%
import pandas as pd

# %%
data=pd.read_csv("insurance.csv")
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
data['charges'].max()
# Out:
# 63770.42801

# %%
import seaborn as sns
sns.pairplot(data)

# %%
b=data["bmi"]

# %%
sns.distplot(b)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
c=data["children"]
sns.distplot(c)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
ch=data["charges"]

# %%
import statsmodels.api as sm
model1=sm.OLS(ch,b).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.564
# Model:                            OLS   Adj. R-squared:                  0.563
# Method:                 Least Squares   F-statistic:                     1726.
# Date:                Thu, 16 May 2019   Prob (F-statistic):          6.10e-243
# Time:                        10:58:11   Log-Likelihood:                -14451.
# No. Observations:                1338   AIC:                         2.890e+04
# Df Residuals:                    1337   BIC:                         2.891e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# bmi          431.2982     10.381     41.546      0.000     410.933     451.663
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(b,ch,test_size=0.3,random_state=1)

# %%
X_train
# Out:
# 744     26.410
# 363     26.400
# 10      26.220
# 970     28.160
# 634     39.700
# 554     41.325
# 314     31.400
# 419     26.980
# 525     33.880
# 1041    23.085
# 649     32.965
# 1306    21.850
# 790     41.800
# 1044    35.245
# 104     27.500
# 1295    22.000
# 370     21.090
# 495     27.930
# 1162    38.830
# 903     36.850
# 125     28.785
# 694     34.800
# 979     29.920
# 1223    24.420
# 1251    19.800
# 529     25.460
# 1018    35.815
# 1139    32.490
# 1011    20.130
# 1097    33.770
#          ...
# 1031    35.200
# 141     32.490
# 1110    32.300
# 753     22.770
# 1001    32.700
# 1239    42.130
# 580     25.460
# 562     30.500
# 398     25.600
# 668     32.015
# 252     34.210
# 907     32.340
# 468     24.320
# 914     24.605
# 357     29.830
# 1278    29.925
# 1300    30.360
# 1202    32.110
# 1305    27.720
# 508     25.270
# 749     30.875
# 129     34.700
# 144     28.690
# 960     39.615
# 847     50.380
# 715     28.900
# 905     29.355
# ...

# %%
X_test
# Out:
# 559     35.530
# 1087    31.540
# 1020    37.000
# 460     36.630
# 802     22.300
# 298     34.390
# 481     37.510
# 616     28.595
# 763     26.030
# 750     26.400
# 48      24.530
# 547     46.700
# 1143    32.340
# 767     29.000
# 194     34.430
# 424     30.200
# 3       22.705
# 785     27.700
# 443     36.520
# 921     33.200
# 315     33.250
# 725     39.050
# 88      27.740
# 310     26.600
# 471     30.115
# 726     28.405
# 60      27.360
# 1280    33.330
# 705     32.900
# 101     25.460
#          ...
# 1197    33.550
# 520     27.360
# 408     21.120
# 403     32.300
# 1084    30.495
# 1276    30.400
# 660     46.530
# 1229    30.305
# 774     34.200
# 909     24.600
# 1196    30.020
# 641     28.310
# 959     36.670
# 264     38.060
# 493     43.400
# 625     26.030
# 1225    39.820
# 927     20.100
# 53      34.430
# 1301    30.875
# 347     33.345
# 1022    36.080
# 1291    34.900
# 1188    25.270
# 764     25.175
# 323     40.945
# 1268    33.300
# ...

# %%
X_train.shape
# Out:
# (936,)

# %%
X_test.shape
# Out:
# (402,)

# %%
X_train=X_train.values.reshape((-1,1))
X_train.shape
# Out:
# (936, 1)

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X_train,y_train)

# %%
results
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
accuracy=model.score(X_train,y_train)
accuracy
# Out:
# 0.03825877603222383

# %%
model.coef_
# Out:
# array([391.88180398])

# %%
model.intercept_
# Out:
# 1252.9086131663844

# %%
X_test=X_test.values.reshape((-1,1))
X_test
# Out:
# array([[35.53 ],
#        [31.54 ],
#        [37.   ],
#        [36.63 ],
#        [22.3  ],
#        [34.39 ],
#        [37.51 ],
#        [28.595],
#        [26.03 ],
#        [26.4  ],
#        [24.53 ],
#        [46.7  ],
#        [32.34 ],
#        [29.   ],
#        [34.43 ],
#        [30.2  ],
#        [22.705],
#        [27.7  ],
#        [36.52 ],
#        [33.2  ],
#        [33.25 ],
#        [39.05 ],
#        [27.74 ],
#        [26.6  ],
#        [30.115],
#        [28.405],
#        [27.36 ],
#        [33.33 ],
#        [32.9  ],
#        [25.46 ],
#        [35.8  ],
#        [27.   ],
#        [22.61 ],
#        [31.92 ],
#        [25.85 ],
#        [24.32 ],
#        [35.3  ],
#        [25.7  ],
#        [39.05 ],
#        [30.495],
#        [33.   ],
#        [34.39 ],
#        [27.83 ],
#        [37.1  ],
#        [23.6  ],
#        [28.595],
#        [35.31 ],
#        [31.68 ],
#        [18.05 ],
#        [28.785],
#        [31.57 ],
#        [29.7  ],
# ...

# %%
predictions=model.predict(X_test)
predictions
# Out:
# array([15176.46910843, 13612.86071056, 15752.53536027, 15607.5390928 ,
#         9991.87284183, 14729.7238519 , 15952.3950803 , 12458.76879786,
#        11453.59197066, 11598.58823813, 10865.76926469, 19553.78885884,
#        13926.36615375, 12617.48092847, 14745.39912405, 13087.73909324,
#        10150.58497244, 12108.0345833 , 15564.43209436, 14263.38450516,
#        14282.97859536, 16555.89305842, 12123.70985546, 11676.96459892,
#        13054.4291399 , 12384.3112551 , 11974.79476995, 14314.32913968,
#        14145.81996397, 11230.21934239, 15282.2771955 , 11833.71732051,
#        10113.35620106, 13761.77579608, 11383.05324594, 10783.47408586,
#        15086.33629351, 11324.27097535, 16555.89305842, 13203.34422541,
#        14185.00814437, 14729.7238519 , 12158.97921781, 15791.72354067,
#        10501.319187  , 12458.76879786, 15090.25511155, 13667.72416312,
#         8326.37517493, 12533.22634061, 13624.61716468, 12891.79819125,
# ...

# %%
y_test
# Out:
# 559      1646.42970
# 1087    11353.22760
# 1020     8798.59300
# 460     10381.47870
# 802      2103.08000
# 298     38746.35510
# 481      9304.70190
# 616     11658.11505
# 763      3070.80870
# 750     19539.24300
# 48      12629.89670
# 547     11538.42100
# 1143     6338.07560
# 767      7050.64200
# 194      1137.46970
# 424      8968.33000
# 3       21984.47061
# 785      6414.17800
# 443     28287.89766
# 921     13462.52000
# 315      9722.76950
# 725     40932.42950
# 88       8026.66660
# 310      8444.47400
# 471      2203.47185
# 726      6664.68595
# 60       8606.21740
# 1280     8283.68070
# 705      5375.03800
# 101      3645.08940
#            ...
# 1197     5699.83750
# 520     25656.57526
# 408      6652.52880
# 403     10269.46000
# 1084    15019.76005
# 1276     2741.94800
# 660      6435.62370
# 1229    11938.25595
# 774      7261.74100
# 909     17496.30600
# 1196    33307.55080
# 641     32787.45859
# 959     28468.91901
# 264     20462.99766
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(X_test,y_test)
plt.plot(X_test,predictions,color='r')

# %%
plt.scatter(b,ch)

# %%
data.smoker=data.smoker.replace('yes',1)
data.smoker=data.smoker.replace('no',0)
data
# Out:
#       age     sex     bmi  children  smoker     region      charges
# 0      19  female  27.900         0       1  southwest  16884.92400
# 1      18    male  33.770         1       0  southeast   1725.55230
# 2      28    male  33.000         3       0  southeast   4449.46200
# 3      33    male  22.705         0       0  northwest  21984.47061
# 4      32    male  28.880         0       0  northwest   3866.85520
# 5      31  female  25.740         0       0  southeast   3756.62160
# 6      46  female  33.440         1       0  southeast   8240.58960
# 7      37  female  27.740         3       0  northwest   7281.50560
# 8      37    male  29.830         2       0  northeast   6406.41070
# 9      60  female  25.840         0       0  northwest  28923.13692
# 10     25    male  26.220         0       0  northeast   2721.32080
# 11     62  female  26.290         0       1  southeast  27808.72510
# 12     23    male  34.400         0       0  southwest   1826.84300
# ...

# %%
data.region=data.region.replace('northeast',1)
data.region=data.region.replace('northwest',2)
data.region=data.region.replace('southeast',3)
data.region=data.region.replace('southwest',4)

# %%
data
# Out:
#       age     sex     bmi  children  smoker  region      charges
# 0      19  female  27.900         0       1       4  16884.92400
# 1      18    male  33.770         1       0       3   1725.55230
# 2      28    male  33.000         3       0       3   4449.46200
# 3      33    male  22.705         0       0       2  21984.47061
# 4      32    male  28.880         0       0       2   3866.85520
# 5      31  female  25.740         0       0       3   3756.62160
# 6      46  female  33.440         1       0       3   8240.58960
# 7      37  female  27.740         3       0       2   7281.50560
# 8      37    male  29.830         2       0       1   6406.41070
# 9      60  female  25.840         0       0       2  28923.13692
# 10     25    male  26.220         0       0       1   2721.32080
# 11     62  female  26.290         0       1       3  27808.72510
# 12     23    male  34.400         0       0       4   1826.84300
# ...

# %%
data.sex=data.sex.replace('female',0)
data.sex=data.sex.replace('male',1)

# %%
data
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       4  16884.92400
# 1      18    1  33.770         1       0       3   1725.55230
# 2      28    1  33.000         3       0       3   4449.46200
# 3      33    1  22.705         0       0       2  21984.47061
# 4      32    1  28.880         0       0       2   3866.85520
# 5      31    0  25.740         0       0       3   3756.62160
# 6      46    0  33.440         1       0       3   8240.58960
# 7      37    0  27.740         3       0       2   7281.50560
# 8      37    1  29.830         2       0       1   6406.41070
# 9      60    0  25.840         0       0       2  28923.13692
# 10     25    1  26.220         0       0       1   2721.32080
# 11     62    0  26.290         0       1       3  27808.72510
# 12     23    1  34.400         0       0       4   1826.84300
# 13     56    0  39.820         0       0       3  11090.71780
# ...

# %%
X=data[['age','sex','bmi','children','smoker','region']]

# %%
y=data['charges']

# %%
model1=sm.OLS(y,X).fit()
predictions=model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.875
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     1557.
# Date:                Thu, 16 May 2019   Prob (F-statistic):               0.00
# Time:                        11:02:07   Log-Likelihood:                -13613.
# No. Observations:                1338   AIC:                         2.724e+04
# Df Residuals:                    1332   BIC:                         2.727e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age          204.0598     11.517     17.719      0.000     181.467     226.653
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#       age  sex     bmi  children  smoker  region
# 216    53    0  26.600         0       0       2
# 731    53    1  21.400         1       0       4
# 866    18    1  37.290         0       0       3
# 202    60    0  24.035         0       0       2
# 820    45    1  33.700         1       0       4
# 986    43    1  30.115         3       0       2
# 776    40    1  32.300         2       0       2
# 288    59    0  36.765         1       1       1
# 8      37    1  29.830         2       0       1
# 241    33    0  22.135         1       0       1
# 604    19    0  28.310         0       1       2
# 1100   33    0  19.095         2       1       1
# 791    19    1  27.600         0       0       4
# 653    45    0  36.300         2       0       3
# 1298   33    1  27.455         2       0       2
# 692    20    1  32.395         1       0       2
# 810    46    0  30.800         3       0       4
# 992    50    0  31.600         2       0       4
# ...

# %%
features=X_train.iloc[:,:].values

# %%
labels=y_train.iloc[:].values

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(features,labels)
results
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions=model.predict(X)

# %%
accuracy=model.score(features,labels)
accuracy
# Out:
# 0.7475615631933097

# %%
import numpy as np

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
y_train_prediction=model.predict(X_train)
y_train_prediction
# Out:
# array([10515.24112081,  8383.47872041,  4277.99031906, ...,
#        37555.38267394, 30041.8002997 , 11806.81065012])

# %%
X_test=X_test.reshape((-1,1))

# %%
rmse_training=(np.sqrt(mean_squared_error(y_train,y_train_prediction)))
rmse_training
# Out:
# 6067.7734770582765

# %%
r2_training=r2_score(y_train,y_train_prediction)
r2_training
# Out:
# 0.7475615631933097

# %%
#multi linear regression

# %%
X=data[['bmi','age']]

# %%
y=data['charges']

# %%
model1=sm.OLS(y,X).fit()
predictions=model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.595
# Model:                            OLS   Adj. R-squared:                  0.594
# Method:                 Least Squares   F-statistic:                     981.2
# Date:                Thu, 16 May 2019   Prob (F-statistic):          6.45e-263
# Time:                        14:10:11   Log-Likelihood:                -14401.
# No. Observations:                1338   AIC:                         2.881e+04
# Df Residuals:                    1336   BIC:                         2.882e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# bmi          172.3943     27.318      6.311      0.000     118.803     225.986
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
model=lm.LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
r=model.fit(X_test,y_test)

# %%
r
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
accuracy=model.score(X_test,y_test)
accuracy
# Out:
# 0.11865386302933012

# %%
model.coef_
# Out:
# array([352.29760302, 235.34295046])

# %%
model.intercept_
# Out:
# -6969.141754534194

# %%
predictions=model.predict(X_test)

# %%
y_test
# Out:
# 559      1646.42970
# 1087    11353.22760
# 1020     8798.59300
# 460     10381.47870
# 802      2103.08000
# 298     38746.35510
# 481      9304.70190
# 616     11658.11505
# 763      3070.80870
# 750     19539.24300
# 48      12629.89670
# 547     11538.42100
# 1143     6338.07560
# 767      7050.64200
# 194      1137.46970
# 424      8968.33000
# 3       21984.47061
# 785      6414.17800
# 443     28287.89766
# 921     13462.52000
# 315      9722.76950
# 725     40932.42950
# 88       8026.66660
# 310      8444.47400
# 471      2203.47185
# 726      6664.68595
# 60       8606.21740
# 1280     8283.68070
# 705      5375.03800
# 101      3645.08940
#            ...
# 1197     5699.83750
# 520     25656.57526
# 408      6652.52880
# 403     10269.46000
# 1084    15019.76005
# 1276     2741.94800
# 660      6435.62370
# 1229    11938.25595
# 774      7261.74100
# 909     17496.30600
# 1196    33307.55080
# 641     32787.45859
# 959     28468.91901
# 264     20462.99766
# ...

# %%
plt.scatter(y_test,predictions)

# %%
ytp=model.predict(X_train)
ytp
# Out:
# array([14102.18546406,  7273.71692473,  8151.67515802, 14718.70626934,
#        19019.56355861, 13473.13045158, 10447.26264256, 17362.45345374,
#         9202.87414392,  5399.82151935, 18294.2398555 ,  7553.50643467,
#        16935.27311944, 18391.449539  , 10720.70264401,  5488.264521  ,
#        14816.73467106,  7577.38930689, 13770.86268435, 17544.82948909,
#         9290.66146022, 11645.07449282, 12043.94874423,  6340.8247203 ,
#         4477.8668439 ,  6236.52832652, 18356.91622226,  8948.52342618,
#        10242.35586391, 10105.49320942, 10891.11686415, 14501.67464259,
#        15527.51635272, 14032.05378613, 20258.33975054, 13028.90762911,
#        21888.78120894, 14820.831816  , 16754.69933032, 10733.40166101,
#        12043.94874423,  9308.64494126, 11153.29149394, 16871.98182555,
#        13769.6328301 ,  9002.22754307, 14595.68919274, 12786.27240036,
#        16732.21112216, 13314.30944577,  9463.32804391,  8311.56120829,
# ...

# %%
rmse_training=(np.sqrt(mean_squared_error(y_train,ytp)))
rmse_training
# Out:
# 11462.171014943351

# %%
r2_training=r2_score(y_train,ytp)
r2_training
# Out:
# 0.11596388101899191
